# %% [markdown]
# <a href="https://colab.research.google.com/github/pmj-chosim/Commit-Project-2023.1.20-2023.2.28-/blob/main/2023.02.16/gpt-neo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 48.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 84.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 18.7 MB/s eta 0:00:00
# ...

# %%
from transformers import GPTNeoForCausalLM, GPT2Tokenizer

# %%
model = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-125M")
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-125M")

# %%
prompt = (
    "Ariticial intelligence is "
)

# %%
input_ids = tokenizer(prompt, return_tensors="pt").input_ids

# %%
print(input_ids)
# Out:
# tensor([[  32,  799, 6652, 4430,  318,  220]])

# %%
gen_tokens = model.generate(
    input_ids,
    do_sample=True, 
    #top_k=50,
    max_length=500, 
    top_p=0.95, 
    temperature=0.9, 
    num_return_sequences=1
)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
gen_text = tokenizer.batch_decode(gen_tokens)[0]
print(gen_text)
# Out:
# Ariticial intelligence is
# used in a variety of ways.
# In the first example, there are
# targets, where an officer has
# a small staff (say, a
# couple of minutes
# or less) and is not
# able to obtain the full
# of information, although not
# the same information
# in the case of an
# extinct class of officers.
# The second example, which
# is more similar,
# is with the Army of
# uggishness (to which
# we are familiar,
# I would say the
# military system of
# what it is today).
# There is a second example,
# where an officer has a
# couple of minutes and
# the staff of the
# couple is not
# able to acquire the
# full information (it
# is a bit vague,
# the staff is too small
# and
# the officer is not
# able to obtain the
# full information).
# And finally, there are
# targets, where an officer has
# the full rank of a
# couple of minutes and
# the staff of the
# couple is not
# able to obtain the
# full information.
# In any of these scenarios,
# the intelligence officer,
# ...
